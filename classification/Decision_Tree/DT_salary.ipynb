# %%
import pandas as pd

# %%
df = pd.read_csv('salaries.csv')
df.head()
# Out:
#   company                  job     degree  salary_more_then_100k
# 0  google      sales executive  bachelors                      0
# 1  google      sales executive    masters                      0
# 2  google     business manager  bachelors                      1
# 3  google     business manager    masters                      1
# 4  google  computer programmer  bachelors                      0

# %%
x = df.drop('salary_more_then_100k',axis = 1)
y = df.salary_more_then_100k

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
x['comp'] = le.fit_transform(x.company)
x['Job'] = le.fit_transform(x.job)
x['deg'] = le.fit_transform(x.degree)

# %%
# from sklearn.preprocessing import LabelEncoder
# le_company = LabelEncoder()
# le_job = LabelEncoder()
# le_degree = LabelEncoder()

# x['company_n'] = le_company.fit_transform(x['company'])
# x['job_n'] = le_job.fit_transform(x['job'])
# x['degree_n'] = le_degree.fit_transform(x['degree'])

# By using separate LabelEncoder objects for each categorical variable, 
# you maintain the integrity and consistency of the encoding process, 
# enabling accurate representation of categorical features in your dataset.

# %%
x = x.drop(['company','job','degree'],axis='columns')

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize = (15,10))
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.4166666666666667, 0.9166666666666666, 'x[0] <= 0.5\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.25, 0.75, 'x[1] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.16666666666666666, 0.5833333333333334, 'x[2] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5833333333333334, 0.75, 'x[0] <= 1.5\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.5, 0.5833333333333334, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6666666666666666, 0.5833333333333334, 'x[1] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5833333333333334, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
# ...

# %%
model.score(x,y)
# Out:
# 1.0

# %%
model.predict([[2,0,0]])
# Out:
# /home/sonali/Documents/jupyter_project/test/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
df.head(5)
# Out:
#   company                  job     degree  salary_more_then_100k
# 0  google      sales executive  bachelors                      0
# 1  google      sales executive    masters                      0
# 2  google     business manager  bachelors                      1
# 3  google     business manager    masters                      1
# 4  google  computer programmer  bachelors                      0

# %%
x.head(5)
# Out:
#    comp  Job  deg
# 0     2    2    0
# 1     2    2    1
# 2     2    0    0
# 3     2    0    1
# 4     2    1    0
