# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv',usecols=['Survived','Pclass','Sex','Age','Fare'])
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
x = df.drop('Survived',axis=1)
y = df.Survived

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
x['sex'] = le.fit_transform(x.Sex)

# %%
x.drop('Sex',axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
# x_train,x_test

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
x.Age = x.Age.fillna(x.Age.mean())

# %%
dt.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize = (15,10))
tree.plot_tree(dt,filled=True)
# Out:
# [Text(0.3353777629573171, 0.98, 'x[3] <= 0.5\ngini = 0.473\nsamples = 891\nvalue = [549, 342]'),
#  Text(0.16185757839721254, 0.94, 'x[0] <= 2.5\ngini = 0.383\nsamples = 314\nvalue = [81, 233]'),
#  Text(0.05749128919860627, 0.9, 'x[1] <= 2.5\ngini = 0.1\nsamples = 170\nvalue = [9, 161]'),
#  Text(0.03832752613240418, 0.86, 'x[0] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0313588850174216, 0.82, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04529616724738676, 0.82, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07665505226480836, 0.86, 'x[2] <= 28.856\ngini = 0.091\nsamples = 168\nvalue = [8, 160]'),
#  Text(0.059233449477351915, 0.82, 'x[2] <= 28.231\ngini = 0.182\nsamples = 69\nvalue = [7, 62]'),
#  Text(0.05226480836236934, 0.78, 'x[1] <= 56.0\ngini = 0.161\nsamples = 68\nvalue = [6, 62]'),
#  Text(0.03832752613240418, 0.74, 'x[1] <= 23.5\ngini = 0.14\nsamples = 66\nvalue = [5, 61]'),
#  Text(0.0313588850174216, 0.7, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.04529616724738676, 0.7, 'x[1] <= 27.5\ngini = 0.174\nsamples = 52\nvalue = [5, 47]'),
#  Text(0.027874564459930314, 0.66, 'x[1] <= 25.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.013937282229965157, 0.62, 'x[2] <= 13.75\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.006968641114982578, 0.58, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.020905923344947737, 0.58, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.041811846689895474, 0.62, 'x[2] <= 17.429\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.03484320557491289, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04878048780487805, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0627177700348432, 0.66, 'x[1] <= 37.0\ngini = 0.093\nsamples = 41\nvalue = [2, 39]'),
#  Text(0.05574912891986063, 0.62, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.06968641114982578, 0.62, 'x[1] <= 39.0\ngini = 0.208\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.0627177700348432, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07665505226480836, 0.58, 'x[2] <= 25.965\ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.06968641114982578, 0.54, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.08362369337979095, 0.54, 'x[2] <= 26.125\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.07665505226480836, 0.5, 'x[1] <= 43.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06968641114982578, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08362369337979095, 0.46, 'x[1] <= 47.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07665505226480836, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09059233449477352, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09059233449477352, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06620209059233449, 0.74, 'x[0] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.059233449477351915, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07317073170731707, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06620209059233449, 0.78, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09407665505226481, 0.82, 'x[2] <= 149.035\ngini = 0.02\nsamples = 99\nvalue = [1, 98]'),
#  Text(0.08710801393728224, 0.78, 'gini = 0.0\nsamples = 81\nvalue = [0, 81]'),
#  Text(0.10104529616724739, 0.78, 'x[2] <= 152.506\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(0.09407665505226481, 0.74, 'x[1] <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08710801393728224, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10104529616724739, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10801393728222997, 0.74, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.26622386759581884, 0.9, 'x[2] <= 23.35\ngini = 0.5\nsamples = 144\nvalue = [72, 72]'),
#  Text(0.20143728222996515, 0.86, 'x[1] <= 36.5\ngini = 0.484\nsamples = 117\nvalue = [48, 69]'),
#  Text(0.17029616724738675, 0.82, 'x[2] <= 7.888\ngini = 0.472\nsamples = 110\nvalue = [42, 68]'),
#  Text(0.1289198606271777, 0.78, 'x[1] <= 30.1\ngini = 0.393\nsamples = 41\nvalue = [11, 30]'),
#  Text(0.12195121951219512, 0.74, 'x[2] <= 6.987\ngini = 0.355\nsamples = 39\nvalue = [9, 30]'),
#  Text(0.11498257839721254, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1289198606271777, 0.7, 'x[2] <= 7.523\ngini = 0.332\nsamples = 38\nvalue = [8, 30]'),
#  Text(0.12195121951219512, 0.66, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.13588850174216027, 0.66, 'x[1] <= 15.0\ngini = 0.375\nsamples = 32\nvalue = [8, 24]'),
#  Text(0.1289198606271777, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14285714285714285, 0.62, 'x[2] <= 7.64\ngini = 0.35\nsamples = 31\nvalue = [7, 24]'),
#  Text(0.1289198606271777, 0.58, 'x[1] <= 26.35\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.12195121951219512, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13588850174216027, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.156794425087108, 0.58, 'x[2] <= 7.781\ngini = 0.293\nsamples = 28\nvalue = [5, 23]'),
#  Text(0.14982578397212543, 0.54, 'x[2] <= 7.763\ngini = 0.375\nsamples = 20\nvalue = [5, 15]'),
#  Text(0.13240418118466898, 0.5, 'x[2] <= 7.744\ngini = 0.291\nsamples = 17\nvalue = [3, 14]'),
#  Text(0.1254355400696864, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.13937282229965156, 0.46, 'x[1] <= 21.5\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.1254355400696864, 0.42, 'x[1] <= 18.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11846689895470383, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13240418118466898, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15331010452961671, 0.42, 'x[1] <= 25.85\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.14634146341463414, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1602787456445993, 0.38, 'gini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.1672473867595819, 0.5, 'x[1] <= 20.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1602787456445993, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17421602787456447, 0.46, 'x[1] <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1672473867595819, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18118466898954705, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16376306620209058, 0.54, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.13588850174216027, 0.74, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21167247386759583, 0.78, 'x[2] <= 10.825\ngini = 0.495\nsamples = 69\nvalue = [31, 38]'),
#  Text(0.17770034843205576, 0.74, 'x[1] <= 19.0\ngini = 0.434\nsamples = 22\nvalue = [15, 7]'),
#  Text(0.16376306620209058, 0.7, 'x[2] <= 10.152\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.156794425087108, 0.66, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.17073170731707318, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1916376306620209, 0.7, 'x[1] <= 30.5\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.18466898954703834, 0.66, 'x[2] <= 7.988\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.17770034843205576, 0.62, 'x[1] <= 25.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.17073170731707318, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.18466898954703834, 0.58, 'x[1] <= 27.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.17770034843205576, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1916376306620209, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1916376306620209, 0.62, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.1986062717770035, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2456445993031359, 0.74, 'x[2] <= 13.908\ngini = 0.449\nsamples = 47\nvalue = [16, 31]'),
#  Text(0.23867595818815332, 0.7, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.25261324041811845, 0.7, 'x[2] <= 15.373\ngini = 0.484\nsamples = 39\nvalue = [16, 23]'),
#  Text(0.2264808362369338, 0.66, 'x[1] <= 29.35\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.21951219512195122, 0.62, 'x[1] <= 28.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.21254355400696864, 0.58, 'x[1] <= 16.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.20557491289198607, 0.54, 'x[1] <= 14.75\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1986062717770035, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21254355400696864, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21951219512195122, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2264808362369338, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23344947735191637, 0.62, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2787456445993031, 0.66, 'x[1] <= 29.35\ngini = 0.4\nsamples = 29\nvalue = [8, 21]'),
#  Text(0.25435540069686413, 0.62, 'x[1] <= 6.5\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.24041811846689895, 0.58, 'x[2] <= 20.167\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.23344947735191637, 0.54, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.24738675958188153, 0.54, 'x[1] <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24041811846689895, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25435540069686413, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2682926829268293, 0.58, 'x[1] <= 21.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.2613240418118467, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.27526132404181186, 0.54, 'x[1] <= 25.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.2682926829268293, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.28222996515679444, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.30313588850174217, 0.62, 'x[1] <= 30.35\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.2961672473867596, 0.58, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.31010452961672474, 0.58, 'x[1] <= 32.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.30313588850174217, 0.54, 'x[2] <= 19.262\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2961672473867596, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.31010452961672474, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3170731707317073, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.23257839721254356, 0.82, 'x[1] <= 55.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.22560975609756098, 0.78, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.23954703832752614, 0.78, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3310104529616725, 0.86, 'x[2] <= 32.881\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.3240418118466899, 0.82, 'x[2] <= 31.331\ngini = 0.278\nsamples = 18\nvalue = [15, 3]'),
#  Text(0.3170731707317073, 0.78, 'x[2] <= 24.808\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.31010452961672474, 0.74, 'x[2] <= 23.8\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.30313588850174217, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3170731707317073, 0.7, 'x[1] <= 19.85\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.31010452961672474, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3240418118466899, 0.66, 'x[1] <= 29.85\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3170731707317073, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3310104529616725, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3240418118466899, 0.74, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.3310104529616725, 0.78, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.33797909407665505, 0.82, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.5088979475174216, 0.94, 'x[1] <= 6.5\ngini = 0.306\nsamples = 577\nvalue = [468, 109]'),
#  Text(0.3519163763066202, 0.9, 'x[0] <= 2.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.34494773519163763, 0.86, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.3588850174216028, 0.86, 'x[2] <= 20.825\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.3519163763066202, 0.82, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.36585365853658536, 0.82, 'x[2] <= 31.331\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.3588850174216028, 0.78, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.37282229965156793, 0.78, 'x[1] <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.36585365853658536, 0.74, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3797909407665505, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.665879518728223, 0.9, 'x[0] <= 1.5\ngini = 0.28\nsamples = 553\nvalue = [460, 93]'),
#  Text(0.4394599303135889, 0.86, 'x[2] <= 26.144\ngini = 0.46\nsamples = 120\nvalue = [77, 43]'),
#  Text(0.4324912891986063, 0.82, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.44642857142857145, 0.82, 'x[1] <= 53.0\ngini = 0.476\nsamples = 110\nvalue = [67, 43]'),
#  Text(0.4172473867595819, 0.78, 'x[2] <= 27.135\ngini = 0.495\nsamples = 89\nvalue = [49, 40]'),
#  Text(0.39372822299651566, 0.74, 'x[2] <= 26.469\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.3867595818815331, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.40069686411149824, 0.7, 'x[1] <= 46.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.39372822299651566, 0.66, 'x[1] <= 40.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.3867595818815331, 0.62, 'x[1] <= 31.85\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.3797909407665505, 0.58, 'x[1] <= 28.85\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.37282229965156793, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3867595818815331, 0.54, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.39372822299651566, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.40069686411149824, 0.62, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4076655052264808, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.44076655052264807, 0.74, 'x[1] <= 17.5\ngini = 0.472\nsamples = 76\nvalue = [47, 29]'),
#  Text(0.4337979094076655, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.44773519163763065, 0.7, 'x[2] <= 387.665\ngini = 0.463\nsamples = 74\nvalue = [47, 27]'),
#  Text(0.44076655052264807, 0.66, 'x[2] <= 134.642\ngini = 0.453\nsamples = 72\nvalue = [47, 25]'),
#  Text(0.4337979094076655, 0.62, 'x[1] <= 27.5\ngini = 0.473\nsamples = 65\nvalue = [40, 25]'),
#  Text(0.4076655052264808, 0.58, 'x[1] <= 24.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.40069686411149824, 0.54, 'x[1] <= 22.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.39372822299651566, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4076655052264808, 0.5, 'x[2] <= 71.279\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.40069686411149824, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4146341463414634, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4146341463414634, 0.54, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.45993031358885017, 0.58, 'x[2] <= 115.442\ngini = 0.444\nsamples = 54\nvalue = [36, 18]'),
#  Text(0.4529616724738676, 0.54, 'x[2] <= 29.1\ngini = 0.426\nsamples = 52\nvalue = [36, 16]'),
#  Text(0.445993031358885, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.45993031358885017, 0.5, 'x[2] <= 30.598\ngini = 0.449\nsamples = 47\nvalue = [31, 16]'),
#  Text(0.42857142857142855, 0.46, 'x[1] <= 29.35\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.42160278745644597, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4355400696864111, 0.42, 'x[1] <= 34.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.42857142857142855, 0.38, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4425087108013937, 0.38, 'x[2] <= 30.1\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4355400696864111, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.44947735191637633, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4912891986062718, 0.46, 'x[1] <= 49.5\ngini = 0.399\nsamples = 40\nvalue = [29, 11]'),
#  Text(0.4843205574912892, 0.42, 'x[1] <= 47.5\ngini = 0.424\nsamples = 36\nvalue = [25, 11]'),
#  Text(0.47038327526132406, 0.38, 'x[1] <= 43.0\ngini = 0.35\nsamples = 31\nvalue = [24, 7]'),
#  Text(0.4634146341463415, 0.34, 'x[1] <= 36.5\ngini = 0.423\nsamples = 23\nvalue = [16, 7]'),
#  Text(0.445993031358885, 0.3, 'x[2] <= 37.55\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.43205574912891986, 0.26, 'x[2] <= 35.25\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.4250871080139373, 0.22, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.43902439024390244, 0.22, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.45993031358885017, 0.26, 'x[2] <= 54.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.4529616724738676, 0.22, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.46689895470383275, 0.22, 'x[2] <= 61.8\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.45993031358885017, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4738675958188153, 0.18, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4808362369337979, 0.3, 'x[2] <= 41.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.4738675958188153, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4878048780487805, 0.26, 'x[2] <= 52.277\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.4808362369337979, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.49477351916376305, 0.22, 'x[1] <= 37.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.4878048780487805, 0.18, 'x[2] <= 52.827\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4808362369337979, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.49477351916376305, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5017421602787456, 0.18, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.47735191637630664, 0.34, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.49825783972125437, 0.38, 'x[2] <= 99.994\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.4912891986062718, 0.34, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5052264808362369, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.49825783972125437, 0.42, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.46689895470383275, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.44773519163763065, 0.62, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.4547038327526132, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.47560975609756095, 0.78, 'x[1] <= 75.5\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.4686411149825784, 0.74, 'x[2] <= 35.077\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.4616724738675958, 0.7, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.47560975609756095, 0.7, 'x[2] <= 42.502\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.4686411149825784, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.48257839721254353, 0.66, 'x[2] <= 78.244\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.47560975609756095, 0.62, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.4895470383275261, 0.62, 'x[2] <= 96.237\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.48257839721254353, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4965156794425087, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.48257839721254353, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8922991071428571, 0.86, 'x[2] <= 51.698\ngini = 0.204\nsamples = 433\nvalue = [383, 50]'),
#  Text(0.7985354965156795, 0.82, 'x[1] <= 13.0\ngini = 0.193\nsamples = 417\nvalue = [372, 45]'),
#  Text(0.7236498257839721, 0.78, 'x[2] <= 17.344\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.7166811846689896, 0.74, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7306184668989547, 0.74, 'x[0] <= 2.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.7236498257839721, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7375871080139372, 0.7, 'x[2] <= 24.212\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.7306184668989547, 0.66, 'x[1] <= 10.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7236498257839721, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7375871080139372, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7445557491289199, 0.66, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8734211672473867, 0.78, 'x[1] <= 32.25\ngini = 0.182\nsamples = 405\nvalue = [364, 41]'),
#  Text(0.8200130662020906, 0.74, 'x[1] <= 30.75\ngini = 0.206\nsamples = 300\nvalue = [265, 35]'),
#  Text(0.7654616724738676, 0.7, 'x[2] <= 23.35\ngini = 0.185\nsamples = 282\nvalue = [253, 29]'),
#  Text(0.758493031358885, 0.66, 'x[2] <= 22.887\ngini = 0.195\nsamples = 265\nvalue = [236, 29]'),
#  Text(0.7515243902439024, 0.62, 'x[2] <= 15.173\ngini = 0.19\nsamples = 264\nvalue = [236, 28]'),
#  Text(0.6772648083623694, 0.58, 'x[2] <= 7.798\ngini = 0.179\nsamples = 241\nvalue = [217, 24]'),
#  Text(0.6132404181184669, 0.54, 'x[2] <= 7.763\ngini = 0.219\nsamples = 96\nvalue = [84, 12]'),
#  Text(0.5749128919860628, 0.5, 'x[1] <= 29.35\ngini = 0.18\nsamples = 80\nvalue = [72, 8]'),
#  Text(0.5470383275261324, 0.46, 'x[1] <= 26.0\ngini = 0.272\nsamples = 37\nvalue = [31, 6]'),
#  Text(0.5331010452961672, 0.42, 'x[2] <= 7.24\ngini = 0.213\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.5261324041811847, 0.38, 'x[1] <= 19.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.519163763066202, 0.34, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.5331010452961672, 0.34, 'x[2] <= 2.006\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.5261324041811847, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5400696864111498, 0.3, 'x[2] <= 7.133\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.5331010452961672, 0.26, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.5470383275261324, 0.26, 'x[2] <= 7.183\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5400696864111498, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.554006968641115, 0.22, 'x[1] <= 22.75\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.5470383275261324, 0.18, 'x[1] <= 21.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5400696864111498, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.554006968641115, 0.14, 'x[2] <= 7.227\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5470383275261324, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5609756097560976, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5609756097560976, 0.18, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5400696864111498, 0.38, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.5609756097560976, 0.42, 'x[1] <= 27.75\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.554006968641115, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5679442508710801, 0.38, 'x[2] <= 7.49\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5609756097560976, 0.34, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5749128919860628, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6027874564459931, 0.46, 'x[2] <= 7.227\ngini = 0.089\nsamples = 43\nvalue = [41, 2]'),
#  Text(0.5958188153310104, 0.42, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.6097560975609756, 0.42, 'x[2] <= 7.24\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.5958188153310104, 0.38, 'x[1] <= 29.85\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.5888501742160279, 0.34, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.6027874564459931, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6236933797909407, 0.38, 'x[2] <= 7.744\ngini = 0.091\nsamples = 21\nvalue = [20, 1]'),
#  Text(0.6167247386759582, 0.34, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.6306620209059234, 0.34, 'gini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.6515679442508711, 0.5, 'x[1] <= 20.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.6445993031358885, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6585365853658537, 0.46, 'x[1] <= 21.5\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.6445993031358885, 0.42, 'x[2] <= 7.785\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6376306620209059, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6515679442508711, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6724738675958188, 0.42, 'x[1] <= 24.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.6655052264808362, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6794425087108014, 0.38, 'x[1] <= 27.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.6655052264808362, 0.34, 'x[1] <= 26.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6585365853658537, 0.3, 'x[1] <= 25.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6515679442508711, 0.26, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6655052264808362, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6724738675958188, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6933797909407665, 0.34, 'x[1] <= 29.35\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.686411149825784, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7003484320557491, 0.3, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7412891986062717, 0.54, 'x[2] <= 7.91\ngini = 0.152\nsamples = 145\nvalue = [133, 12]'),
#  Text(0.7003484320557491, 0.5, 'x[1] <= 28.5\ngini = 0.048\nsamples = 41\nvalue = [40, 1]'),
#  Text(0.6933797909407665, 0.46, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.7073170731707317, 0.46, 'x[1] <= 29.35\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.7003484320557491, 0.42, 'x[2] <= 7.885\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6933797909407665, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7073170731707317, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7142857142857143, 0.42, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.7822299651567944, 0.5, 'x[1] <= 20.5\ngini = 0.189\nsamples = 104\nvalue = [93, 11]'),
#  Text(0.759581881533101, 0.46, 'x[2] <= 8.104\ngini = 0.293\nsamples = 28\nvalue = [23, 5]'),
#  Text(0.735191637630662, 0.42, 'x[1] <= 18.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.7212543554006968, 0.38, 'x[1] <= 17.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7142857142857143, 0.34, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7282229965156795, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7491289198606271, 0.38, 'x[2] <= 7.988\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.7421602787456446, 0.34, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7560975609756098, 0.34, 'x[1] <= 19.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7491289198606271, 0.3, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7630662020905923, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7839721254355401, 0.42, 'x[0] <= 2.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.7770034843205574, 0.38, 'x[1] <= 18.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.7700348432055749, 0.34, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7839721254355401, 0.34, 'x[2] <= 11.75\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7770034843205574, 0.3, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7909407665505227, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7909407665505227, 0.38, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.8048780487804879, 0.46, 'x[1] <= 26.5\ngini = 0.145\nsamples = 76\nvalue = [70, 6]'),
#  Text(0.7979094076655052, 0.42, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.8118466898954704, 0.42, 'x[2] <= 8.081\ngini = 0.227\nsamples = 46\nvalue = [40, 6]'),
#  Text(0.8048780487804879, 0.38, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.818815331010453, 0.38, 'x[2] <= 8.285\ngini = 0.328\nsamples = 29\nvalue = [23, 6]'),
#  Text(0.8118466898954704, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8257839721254355, 0.34, 'x[2] <= 14.158\ngini = 0.293\nsamples = 28\nvalue = [23, 5]'),
#  Text(0.818815331010453, 0.3, 'x[2] <= 13.681\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.8118466898954704, 0.26, 'x[2] <= 10.0\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.7979094076655052, 0.22, 'x[1] <= 27.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.7909407665505227, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8048780487804879, 0.18, 'x[1] <= 29.85\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.7979094076655052, 0.14, 'x[2] <= 9.492\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.7909407665505227, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8048780487804879, 0.1, 'x[1] <= 28.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.7979094076655052, 0.06, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8118466898954704, 0.06, 'x[1] <= 29.35\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8048780487804879, 0.02, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.818815331010453, 0.02, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8118466898954704, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8257839721254355, 0.22, 'x[1] <= 29.35\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.818815331010453, 0.18, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.8327526132404182, 0.18, 'x[1] <= 29.85\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.8257839721254355, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8397212543554007, 0.14, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8257839721254355, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8327526132404182, 0.3, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.8257839721254355, 0.58, 'x[2] <= 15.373\ngini = 0.287\nsamples = 23\nvalue = [19, 4]'),
#  Text(0.818815331010453, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8327526132404182, 0.54, 'x[1] <= 27.0\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.8257839721254355, 0.5, 'x[2] <= 15.921\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.818815331010453, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8327526132404182, 0.46, 'x[1] <= 25.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.8257839721254355, 0.42, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.8397212543554007, 0.42, 'x[2] <= 19.681\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8327526132404182, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8466898954703833, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8397212543554007, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.7654616724738676, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7724303135888502, 0.66, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.8745644599303136, 0.7, 'x[2] <= 7.815\ngini = 0.444\nsamples = 18\nvalue = [12, 6]'),
#  Text(0.867595818815331, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8815331010452961, 0.66, 'x[2] <= 7.875\ngini = 0.48\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.8745644599303136, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8885017421602788, 0.62, 'x[2] <= 26.125\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.8815331010452961, 0.58, 'x[2] <= 20.925\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.8745644599303136, 0.54, 'x[1] <= 31.5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.8536585365853658, 0.5, 'x[2] <= 9.213\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8466898954703833, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8606271777003485, 0.46, 'x[2] <= 11.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8536585365853658, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.867595818815331, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8954703832752613, 0.5, 'x[2] <= 8.206\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.8885017421602788, 0.46, 'x[2] <= 7.988\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.8815331010452961, 0.42, 'x[2] <= 7.91\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8745644599303136, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8885017421602788, 0.38, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8954703832752613, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9024390243902439, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8885017421602788, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8954703832752613, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.926829268292683, 0.74, 'x[2] <= 7.91\ngini = 0.108\nsamples = 105\nvalue = [99, 6]'),
#  Text(0.9198606271777003, 0.7, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.9337979094076655, 0.7, 'x[2] <= 7.988\ngini = 0.151\nsamples = 73\nvalue = [67, 6]'),
#  Text(0.9094076655052264, 0.66, 'x[1] <= 38.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.9024390243902439, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9163763066202091, 0.62, 'x[1] <= 41.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9094076655052264, 0.58, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9233449477351916, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9581881533101045, 0.66, 'x[1] <= 61.0\ngini = 0.109\nsamples = 69\nvalue = [65, 4]'),
#  Text(0.9442508710801394, 0.62, 'x[2] <= 13.25\ngini = 0.087\nsamples = 66\nvalue = [63, 3]'),
#  Text(0.9372822299651568, 0.58, 'x[2] <= 12.938\ngini = 0.157\nsamples = 35\nvalue = [32, 3]'),
#  Text(0.9163763066202091, 0.54, 'x[1] <= 44.5\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(0.9094076655052264, 0.5, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.9233449477351916, 0.5, 'x[1] <= 46.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.9163763066202091, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9303135888501742, 0.46, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.9581881533101045, 0.54, 'x[1] <= 45.0\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.9512195121951219, 0.5, 'x[1] <= 40.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.9442508710801394, 0.46, 'x[1] <= 35.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.9372822299651568, 0.42, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9512195121951219, 0.42, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9581881533101045, 0.46, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9651567944250871, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9512195121951219, 0.58, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.9721254355400697, 0.62, 'x[1] <= 64.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9651567944250871, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9790940766550522, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9860627177700348, 0.82, 'x[2] <= 63.023\ngini = 0.43\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.9790940766550522, 0.78, 'x[1] <= 30.85\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.9721254355400697, 0.74, 'x[1] <= 27.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.9651567944250871, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9790940766550522, 0.7, 'x[1] <= 28.85\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.9721254355400697, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9860627177700348, 0.66, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9860627177700348, 0.74, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9930313588850174, 0.78, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]')]

# %%
dt.predict([[1,38,71,0]])
# Out:
# /home/sonali/Documents/jupyter_project/test/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
x.head(2)
# Out:
#    Pclass   Age     Fare  sex
# 0       3  22.0   7.2500    1
# 1       1  38.0  71.2833    0

# %%
dt.score(x,y)
# Out:
# 0.9797979797979798
