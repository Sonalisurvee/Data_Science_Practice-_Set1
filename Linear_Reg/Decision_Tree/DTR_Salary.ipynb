# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor

# %%
df = pd.read_csv('Salary_Data.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x = df.YearsExperience.values.reshape(-1,1)
y = df.Salary.values.reshape(-1,1)

# %%
reg = DecisionTreeRegressor(random_state=0)
reg.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# reg.score(x_test,y_test)

# %%
plt.scatter(x,y)
plt.show()

# %%
# this is not a DT graph or Decison boundry
plt.scatter(x,y)
plt.plot(x,reg.predict(x))
plt.show()

# %%
x_grid = np.arange(min(x),max(x),0.01)
x_grid = x_grid.reshape((len(x_grid),1))
plt.scatter(x,y)
plt.plot(x_grid,reg.predict(x_grid))
plt.show()

# %%
from sklearn import tree
plt.figure(figsize = (15,10))
tree.plot_tree(reg,filled=True)
# tree.plot_tree(classifier,filled=False) #no color where there
# Out:
# [Text(0.4817073170731707, 0.95, 'x[0] <= 5.2\nsquared_error = 726499261.733\nsamples = 30\nvalue = 76003.0'),
#  Text(0.23170731707317074, 0.85, 'x[0] <= 2.55\nsquared_error = 88456323.003\nsamples = 17\nvalue = 54570.235'),
#  Text(0.0975609756097561, 0.75, 'x[0] <= 1.4\nsquared_error = 9510987.2\nsamples = 5\nvalue = 41339.0'),
#  Text(0.04878048780487805, 0.65, 'x[0] <= 1.2\nsquared_error = 11771761.0\nsamples = 2\nvalue = 42774.0'),
#  Text(0.024390243902439025, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 39343.0'),
#  Text(0.07317073170731707, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 46205.0'),
#  Text(0.14634146341463414, 0.65, 'x[0] <= 1.75\nsquared_error = 5715776.889\nsamples = 3\nvalue = 40382.333'),
#  Text(0.12195121951219512, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 37731.0'),
#  Text(0.17073170731707318, 0.55, 'x[0] <= 2.1\nsquared_error = 3301489.0\nsamples = 2\nvalue = 41708.0'),
#  Text(0.14634146341463414, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 43525.0'),
#  Text(0.1951219512195122, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 39891.0'),
#  Text(0.36585365853658536, 0.75, 'x[0] <= 4.7\nsquared_error = 18012887.021\nsamples = 12\nvalue = 60083.25'),
#  Text(0.3170731707317073, 0.65, 'x[0] <= 4.3\nsquared_error = 10006022.36\nsamples = 10\nvalue = 58703.2'),
#  Text(0.2926829268292683, 0.55, 'x[0] <= 3.95\nsquared_error = 10402061.778\nsamples = 9\nvalue = 58435.667'),
#  Text(0.24390243902439024, 0.45, 'x[0] <= 3.8\nsquared_error = 12937106.472\nsamples = 6\nvalue = 59348.167'),
#  Text(0.21951219512195122, 0.35, 'x[0] <= 2.95\nsquared_error = 11930381.36\nsamples = 5\nvalue = 58574.2'),
#  Text(0.1951219512195122, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 56642.0'),
#  Text(0.24390243902439024, 0.25, 'x[0] <= 3.45\nsquared_error = 13746290.188\nsamples = 4\nvalue = 59057.25'),
#  Text(0.21951219512195122, 0.15, 'x[0] <= 3.1\nsquared_error = 16777116.667\nsamples = 3\nvalue = 59680.0'),
#  Text(0.1951219512195122, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 60150.0'),
#  Text(0.24390243902439024, 0.05, 'squared_error = 25000000.0\nsamples = 2\nvalue = 59445.0'),
#  Text(0.2682926829268293, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 57189.0'),
#  Text(0.2682926829268293, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 63218.0'),
#  Text(0.34146341463414637, 0.45, 'x[0] <= 4.05\nsquared_error = 336034.889\nsamples = 3\nvalue = 56610.667'),
#  Text(0.3170731707317073, 0.35, 'squared_error = 338142.25\nsamples = 2\nvalue = 56375.5'),
#  Text(0.36585365853658536, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 57081.0'),
#  Text(0.34146341463414637, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 61111.0'),
#  Text(0.4146341463414634, 0.65, 'x[0] <= 5.0\nsquared_error = 911070.25\nsamples = 2\nvalue = 66983.5'),
#  Text(0.3902439024390244, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 67938.0'),
#  Text(0.43902439024390244, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 66029.0'),
#  Text(0.7317073170731707, 0.85, 'x[0] <= 8.05\nsquared_error = 174618515.941\nsamples = 13\nvalue = 104030.462'),
#  Text(0.573170731707317, 0.75, 'x[0] <= 5.95\nsquared_error = 53566814.556\nsamples = 6\nvalue = 91617.333'),
#  Text(0.5121951219512195, 0.65, 'x[0] <= 5.6\nsquared_error = 743906.25\nsamples = 2\nvalue = 82225.5'),
#  Text(0.4878048780487805, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 83088.0'),
#  Text(0.5365853658536586, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 81363.0'),
#  Text(0.6341463414634146, 0.65, 'x[0] <= 6.95\nsquared_error = 13823368.688\nsamples = 4\nvalue = 96313.25'),
#  Text(0.5853658536585366, 0.55, 'x[0] <= 6.4\nsquared_error = 1212201.0\nsamples = 2\nvalue = 92839.0'),
#  Text(0.5609756097560976, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 93940.0'),
#  Text(0.6097560975609756, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 91738.0'),
#  Text(0.6829268292682927, 0.55, 'x[0] <= 7.5\nsquared_error = 2293710.25\nsamples = 2\nvalue = 99787.5'),
#  Text(0.6585365853658537, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 98273.0'),
#  Text(0.7073170731707317, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 101302.0'),
#  Text(0.8902439024390244, 0.75, 'x[0] <= 9.95\nsquared_error = 33097757.061\nsamples = 7\nvalue = 114670.286'),
#  Text(0.8292682926829268, 0.65, 'x[0] <= 9.25\nsquared_error = 15134881.36\nsamples = 5\nvalue = 111685.8'),
#  Text(0.7804878048780488, 0.55, 'x[0] <= 8.45\nsquared_error = 11304540.222\nsamples = 3\nvalue = 109608.333'),
#  Text(0.7560975609756098, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 113812.0'),
#  Text(0.8048780487804879, 0.45, 'x[0] <= 8.85\nsquared_error = 3703700.25\nsamples = 2\nvalue = 107506.5'),
#  Text(0.7804878048780488, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 109431.0'),
#  Text(0.8292682926829268, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 105582.0'),
#  Text(0.8780487804878049, 0.55, 'x[0] <= 9.55\nsquared_error = 4695889.0\nsamples = 2\nvalue = 114802.0'),
#  Text(0.8536585365853658, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 116969.0'),
#  Text(0.9024390243902439, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 112635.0'),
#  Text(0.9512195121951219, 0.65, 'x[0] <= 10.4\nsquared_error = 67340.25\nsamples = 2\nvalue = 122131.5'),
#  Text(0.926829268292683, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 122391.0'),
#  Text(0.975609756097561, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 121872.0')]
