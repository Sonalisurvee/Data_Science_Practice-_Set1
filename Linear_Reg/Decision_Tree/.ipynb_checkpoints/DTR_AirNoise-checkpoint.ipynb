# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("airfoil_noise_data.csv")
data.head(5)
# Out:
#      x0   x1      x2    x3        x4        y
# 0   800  0.0  0.3048  71.3  0.002663  126.201
# 1  1000  0.0  0.3048  71.3  0.002663  125.201
# 2  1250  0.0  0.3048  71.3  0.002663  125.951
# 3  1600  0.0  0.3048  71.3  0.002663  127.591
# 4  2000  0.0  0.3048  71.3  0.002663  127.461

# %%
X = data.iloc[:, :-1].values
Y = data.iloc[:, -1].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=41)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(min_samples_split=3, max_depth=3)
regressor.fit(X_train,Y_train)
# regressor.print_tree()
# Out:
# DecisionTreeRegressor(max_depth=3, min_samples_split=3)

# %%
Y_pred = regressor.predict(X_test)

# %%
regressor.score(X_test,Y_test)
# Out:
# 0.49194628493897596

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(Y_test, Y_pred))
# Out:
# 5.3769795899246855

# %%
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize = (15,10))
tree.plot_tree(regressor,filled=True)
# Out:
# [Text(0.5, 0.875, 'x[0] <= 3575.0\nsquared_error = 45.073\nsamples = 1202\nvalue = 125.007'),
#  Text(0.25, 0.625, 'x[4] <= 0.034\nsquared_error = 30.457\nsamples = 878\nvalue = 126.63'),
#  Text(0.125, 0.375, 'x[3] <= 63.4\nsquared_error = 26.488\nsamples = 785\nvalue = 127.282'),
#  Text(0.0625, 0.125, 'squared_error = 25.354\nsamples = 553\nvalue = 126.578'),
#  Text(0.1875, 0.125, 'squared_error = 25.202\nsamples = 232\nvalue = 128.958'),
#  Text(0.375, 0.375, 'x[0] <= 1425.0\nsquared_error = 30.064\nsamples = 93\nvalue = 121.124'),
#  Text(0.3125, 0.125, 'squared_error = 22.938\nsamples = 68\nvalue = 123.039'),
#  Text(0.4375, 0.125, 'squared_error = 12.354\nsamples = 25\nvalue = 115.917'),
#  Text(0.75, 0.625, 'x[4] <= 0.001\nsquared_error = 58.22\nsamples = 324\nvalue = 120.611'),
#  Text(0.625, 0.375, 'x[0] <= 9000.0\nsquared_error = 29.351\nsamples = 81\nvalue = 129.952'),
#  Text(0.5625, 0.125, 'squared_error = 14.651\nsamples = 51\nvalue = 132.596'),
#  Text(0.6875, 0.125, 'squared_error = 22.248\nsamples = 30\nvalue = 125.456'),
#  Text(0.875, 0.375, 'x[4] <= 0.023\nsquared_error = 29.066\nsamples = 243\nvalue = 117.497'),
#  Text(0.8125, 0.125, 'squared_error = 23.974\nsamples = 208\nvalue = 118.471'),
#  Text(0.9375, 0.125, 'squared_error = 20.179\nsamples = 35\nvalue = 111.709')]
