# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# Load the California Housing Prices dataset
cali_housing = fetch_california_housing()
X = cali_housing.data  # Features
y = cali_housing.target  # Target variable (median house value)

# Choose an independent variable (feature) for both linear and polynomial regression
feature_index = 5  # Median income feature
X_feature = X[:, feature_index]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_feature, y, test_size=0.2, random_state=42)

# Linear Regression
linear_model = LinearRegression()
linear_model.fit(X_train.reshape(-1, 1), y_train)
y_linear_pred = linear_model.predict(X_test.reshape(-1, 1))

# Polynomial Regression (Degree = 2)
degree_of_polynomial = 2
poly_features = PolynomialFeatures(degree=degree_of_polynomial)
X_train_poly = poly_features.fit_transform(X_train.reshape(-1, 1))
X_test_poly = poly_features.transform(X_test.reshape(-1, 1))

poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)
y_poly_pred = poly_model.predict(X_test_poly)

# Evaluate models
mse_linear = mean_squared_error(y_test, y_linear_pred)
r2_linear = r2_score(y_test, y_linear_pred)

mse_poly = mean_squared_error(y_test, y_poly_pred)
r2_poly = r2_score(y_test, y_poly_pred)

# Print MSE and R-squared for both models
print("Linear Regression - Mean Squared Error:", mse_linear)
print("Linear Regression - R-squared:", r2_linear)
print("Polynomial Regression (Degree = 2) - Mean Squared Error:", mse_poly)
print("Polynomial Regression (Degree = 2) - R-squared:", r2_poly)

# Plot the data and the regression curves
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_linear_pred, color='red', label='Linear Regression')
plt.plot(X_test, y_poly_pred, color='green', label='Polynomial Regression (Degree = 2)')
plt.xlabel("Median Income")
plt.ylabel("Median House Value")
plt.title("Linear vs. Polynomial Regression - California Housing Prices")
plt.legend()
plt.show()
# Out:
# Linear Regression - Mean Squared Error: 1.3096449354773076
# Linear Regression - R-squared: 0.0005830567221980498
# Polynomial Regression (Degree = 2) - Mean Squared Error: 1.3031808822661435
# Polynomial Regression (Degree = 2) - R-squared: 0.005515908464286734
